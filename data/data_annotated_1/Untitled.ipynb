# %%
from PIL import Image
import PIL
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
image = PIL.Image.open("bracketsample_000180.jpg")
image.size
# Out:
# (416, 416)

# %%
im = Image.open('bracketsample_000184.jpg')

# Create figure and axes
fig, ax = plt.subplots()

# Display the image
ax.imshow(im)

# Create a Rectangle patch
rect = patches.Rectangle((0.256010*416, 0.608173*416), 0.257212*416, 0.533654*416, linewidth=0.5, edgecolor='r', facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()

# %%
im = Image.open('bracketsample_000180.jpg')

# Create figure and axes
fig, ax = plt.subplots()

# Display the image
ax.imshow(im)

# Create a Rectangle patch
rect = patches.Rectangle((26, 196), 25, 41, linewidth=0.5, edgecolor='r', facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()

# %%
import os
path = r'C:\Users\nguy\Documents\TrungKien\Project\IDEE\Gits\labelImg\data\data_test_1_1\bracketsample_000180'
os.path.abspath(path)
# Out:
# 'C:\\Users\\nguy\\Documents\\TrungKien\\Project\\IDEE\\Gits\\labelImg\\data\\data_test_1_1\\bracketsample_000180'

# %%
os.path.dirname(path)
# Out:
# 'C:\\Users\\nguy\\Documents\\TrungKien\\Project\\IDEE\\Gits\\labelImg\\data\\data_test_1_1'

# %%
os.path.basename(path)
# Out:
# 'bracketsample_000180'

# %%
import cv2
 
img = cv2.imread('bracketsample_000726.jpg', cv2.IMREAD_UNCHANGED)
 
print('Original Dimensions : ',img.shape)
po = img.shape
width = 416
height = 416
dim = (width, height)
 
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
 
print('Resized Dimensions : ',resized.shape)
 
cv2.imwrite('resized.jpg',resized)
# Out:
# Original Dimensions :  (918, 1756, 3)
# Resized Dimensions :  (416, 416, 3)
# True

# %%
po[0]
# Out:
# 918

# %%
im = Image.open('bracketsample_000726.jpg')

# Create figure and axes
fig, ax = plt.subplots()

# Display the image
ax.imshow(im)

# Create a Rectangle patch
rect = patches.Rectangle((490, 275), 667, 324, linewidth=0.5, edgecolor='r', facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()

# %%
im = Image.open('resized.jpg')

# Create figure and axes
fig, ax = plt.subplots()

# Display the image
ax.imshow(im)
left = 1395
top = 658
width = 257
height = 221

left_resized = 45
top_resized = 188
width_resized = 18
height_resized = 69


# Create a Rectangle patch
rect = patches.Rectangle((left_resized, top_resized), width_resized, height_resized, linewidth=0.5, edgecolor='r', facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()
